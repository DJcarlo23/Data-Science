# %%
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, auc, roc_curve
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder

from lightgbm import LGBMClassifier

import warnings
warnings.filterwarnings('ignore')

# %%
data_train = pd.read_csv('D:/Python/Anaconda/Kaggle/Working/Tabular Playground Apr 2021/data/train.csv')

data_test = pd.read_csv('D:/Python/Anaconda/Kaggle/Working/Tabular Playground Apr 2021/data/test.csv')

# %%
data_train
# Out:
#        PassengerId  Survived  Pclass                Name     Sex    Age  \
# 0                0         1       1    Oconnor, Frankie    male    NaN
# 1                1         0       3         Bryan, Drew    male    NaN
# 2                2         0       3      Owens, Kenneth    male   0.33
# 3                3         0       3       Kramer, James    male  19.00
# 4                4         1       3       Bond, Michael    male  25.00
# ...            ...       ...     ...                 ...     ...    ...
# 99995        99995         1       2         Bell, Adele  female  62.00
# 99996        99996         0       2       Brown, Herman    male  66.00
# 99997        99997         0       3  Childress, Charles    male  37.00
# 99998        99998         0       3    Caughlin, Thomas    male  51.00
# 99999        99999         0       3       Enciso, Tyler    male  55.00
#
#        SibSp  Parch     Ticket   Fare   Cabin Embarked
# 0          2      0     209245  27.14  C12239        S
# 1          0      0      27323  13.35     NaN        S
# 2          1      2  CA 457703  71.29     NaN        S
# 3          0      0   A. 10866  13.04     NaN        S
# 4          0      0     427635   7.76     NaN        S
# ...      ...    ...        ...    ...     ...      ...
# 99995      0      0   PC 15008  14.86  D17243        C
# 99996      0      0      13273  11.15     NaN        S
# 99997      0      0        NaN   9.95     NaN        S
# 99998      0      1     458654  30.92     NaN        S
# 99999      0      0     458074  13.96     NaN        S
#
# [100000 rows x 12 columns]

# %%
print('Missing values in train dataset')
print(data_train.isnull().sum())
# Out:
# Missing values in train dataset
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age             3292
# SibSp              0
# Parch              0
# Ticket          4623
# Fare             134
# Cabin          67866
# Embarked         250
# dtype: int64

# %%
print('Unique values in train dataset')
print(data_train.nunique())
# Out:
# Unique values in train dataset
# PassengerId    100000
# Survived            2
# Pclass              3
# Name            92144
# Sex                 2
# Age               173
# SibSp               7
# Parch               8
# Ticket          75331
# Fare            15935
# Cabin           26992
# Embarked            3
# dtype: int64

# %%
print('Missing values in test dataset')
print(data_test.isnull().sum())
# Out:
# Missing values in test dataset
# PassengerId        0
# Pclass             0
# Name               0
# Sex                0
# Age             3487
# SibSp              0
# Parch              0
# Ticket          5181
# Fare             133
# Cabin          70831
# Embarked         277
# dtype: int64

# %%
print('Missing values in test dataset')
print(data_test.nunique())
# Out:
# Missing values in test dataset
# PassengerId    100000
# Pclass              3
# Name            90808
# Sex                 2
# Age               159
# SibSp               7
# Parch               8
# Ticket          75432
# Fare            16554
# Cabin           25216
# Embarked            3
# dtype: int64

# %%
def label_encoder(column):
    lc = LabelEncoder()
    return lc.fit_transform(column)

# %%
def titanic_preprocessing(df):
    age = df[['Age', 'Pclass']].dropna().groupby('Pclass').mean().to_dict()
    df['Age'] = df['Age'].fillna(df['Pclass'].map(age['Age']))

    df['Fare'].fillna(df['Fare'].median(), inplace=True)

    df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

    # Ticked
    df['Ticket'] = df['Ticket'].fillna('X').map(lambda x: str(x).split()[0] if len(str(x).split()) > 1 else 'X')

    # Cabin
    df['Cabin'] = df['Cabin'].fillna('X').map(lambda x: x[0].strip())

    # Surname
    df['Surname'] = df['Name'].map(lambda x: x.split(',')[0])

    df.drop(['PassengerId'], axis=1, inplace=True)

    return df

# %%
def titanic_feature_engineering(df):
    # Create dummy variables
    dummy = pd.get_dummies(df[['Embarked', 'Cabin']], dtype=np.int32)
    df = pd.concat([df, dummy], axis=1)
    df.drop(['Embarked', 'Cabin'], axis=1, inplace=True)

    # Label Encoder
    ticket_labeled = df[['Ticket', 'Surname']].apply(label_encoder)
    ticket_labeled.columns = ['Ticket labeled', 'Surname Labeled']
    df = pd.concat([df, ticket_labeled], axis=1)
    df.drop(['Ticket', 'Surname', 'Name'], axis=1, inplace=True)

    df['Sex_dummy'] = df['Sex'].map({'male': 0, 'female': 1})
    df.drop(['Sex'], axis=1, inplace=True)

    return df

# %%
def dataset_preparation(df):
    df = titanic_preprocessing(df)
    df = titanic_feature_engineering(df)
    return df

# %%
data_train_copy = data_train.copy()
data_test_copy = data_test.copy()

data_train_prep = dataset_preparation(data_train_copy)
data_test_prep = dataset_preparation(data_test_copy)

# %%
data_train_prep
# Out:
#        Survived  Pclass        Age  SibSp  Parch   Fare  Embarked_C  \
# 0             1       1  44.774464      2      0  27.14           0
# 1             0       3  33.407362      0      0  13.35           0
# 2             0       3   0.330000      1      2  71.29           0
# 3             0       3  19.000000      0      0  13.04           0
# 4             1       3  25.000000      0      0   7.76           0
# ...         ...     ...        ...    ...    ...    ...         ...
# 99995         1       2  62.000000      0      0  14.86           1
# 99996         0       2  66.000000      0      0  11.15           0
# 99997         0       3  37.000000      0      0   9.95           0
# 99998         0       3  51.000000      0      1  30.92           0
# 99999         0       3  55.000000      0      0  13.96           0
#
#        Embarked_Q  Embarked_S  Cabin_A  ...  Cabin_C  Cabin_D  Cabin_E  \
# 0               0           1        0  ...        1        0        0
# 1               0           1        0  ...        0        0        0
# 2               0           1        0  ...        0        0        0
# 3               0           1        0  ...        0        0        0
# 4               0           1        0  ...        0        0        0
# ...           ...         ...      ...  ...      ...      ...      ...
# 99995           0           0        0  ...        0        1        0
# 99996           0           1        0  ...        0        0        0
# 99997           0           1        0  ...        0        0        0
# 99998           0           1        0  ...        0        0        0
# 99999           0           1        0  ...        0        0        0
#
#        Cabin_F  Cabin_G  Cabin_T  Cabin_X  Ticket labeled  Surname Labeled  \
# 0            0        0        0        0              49            14195
# 1            0        0        0        1              49             2495
# 2            0        0        0        1              14            14478
# 3            0        0        0        1               0            10435
# 4            0        0        0        1              49             1902
# ...        ...      ...      ...      ...             ...              ...
# 99995        0        0        0        0              21             1301
# 99996        0        0        0        1              49             2436
# 99997        0        0        0        1              49             3463
# 99998        0        0        0        1              49             3226
# 99999        0        0        0        1              49             5762
#
#        Sex_dummy
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 99995          1
# 99996          0
# 99997          0
# 99998          0
# 99999          0
#
# [100000 rows x 21 columns]

# %%
data_train_prep
# Out:
#        Survived  Pclass        Age  SibSp  Parch   Fare  Embarked_C  \
# 0             1       1  44.774464      2      0  27.14           0
# 1             0       3  33.407362      0      0  13.35           0
# 2             0       3   0.330000      1      2  71.29           0
# 3             0       3  19.000000      0      0  13.04           0
# 4             1       3  25.000000      0      0   7.76           0
# ...         ...     ...        ...    ...    ...    ...         ...
# 99995         1       2  62.000000      0      0  14.86           1
# 99996         0       2  66.000000      0      0  11.15           0
# 99997         0       3  37.000000      0      0   9.95           0
# 99998         0       3  51.000000      0      1  30.92           0
# 99999         0       3  55.000000      0      0  13.96           0
#
#        Embarked_Q  Embarked_S  Cabin_A  ...  Cabin_C  Cabin_D  Cabin_E  \
# 0               0           1        0  ...        1        0        0
# 1               0           1        0  ...        0        0        0
# 2               0           1        0  ...        0        0        0
# 3               0           1        0  ...        0        0        0
# 4               0           1        0  ...        0        0        0
# ...           ...         ...      ...  ...      ...      ...      ...
# 99995           0           0        0  ...        0        1        0
# 99996           0           1        0  ...        0        0        0
# 99997           0           1        0  ...        0        0        0
# 99998           0           1        0  ...        0        0        0
# 99999           0           1        0  ...        0        0        0
#
#        Cabin_F  Cabin_G  Cabin_T  Cabin_X  Ticket labeled  Surname Labeled  \
# 0            0        0        0        0              49            14195
# 1            0        0        0        1              49             2495
# 2            0        0        0        1              14            14478
# 3            0        0        0        1               0            10435
# 4            0        0        0        1              49             1902
# ...        ...      ...      ...      ...             ...              ...
# 99995        0        0        0        0              21             1301
# 99996        0        0        0        1              49             2436
# 99997        0        0        0        1              49             3463
# 99998        0        0        0        1              49             3226
# 99999        0        0        0        1              49             5762
#
#        Sex_dummy
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 99995          1
# 99996          0
# 99997          0
# 99998          0
# 99999          0
#
# [100000 rows x 21 columns]

# %%
plt.figure(figsize=(8, 12))

heatmap = sns.heatmap(data_train_prep.corr()[['Survived']].sort_values(by='Survived', ascending=False),
                     vmin=-1, vmax=1, annot=True, cmap='BrBG')

heatmap.set_title('Features correlated with chance of stroke', fontdict={'fontsize': 18}, pad=16);

# %%
# Split data into train and validation sets
X = data_train_prep.drop(['Survived'], axis=1)
y = data_train_prep['Survived']

# Scalling
# scaler = StandardScaler()
# X[X.columns] = scaler.fit_transform(X[X.columns])
# data_test_scaled = scaler.fit_transform(data_test_prep)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
def model_evaluation(model):
    # Train our model
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # F1 score
    scores_f1 = cross_val_score(model, X, y, scoring = 'f1' ,cv=5)
    print('F1 scores: {}'.format(scores_f1))
    print('F1 mean score: {}'.format(scores_f1.mean()))

    # Accuracy score
    scores_acc = cross_val_score(model, X, y, cv=5)
    print('Acc scores: {}'.format(scores_acc))
    print('Acc mean score: {}'.format(scores_acc.mean()))
    
    # Confusion matrix
    print('Confusion Matrix: ')
    matrix = confusion_matrix(y_test, y_pred)
    group_names = ['True Negative','False Positive','False Negative','True Positive']
    group_counts =['{0:0.0f}'.format(value) for value in matrix.flatten()]
    group_percentages = ['{0:.2%}'.format(value) for value in matrix.flatten()/np.sum(matrix)]
    
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2, 2)

    sns.heatmap(matrix, annot=labels, fmt='', cmap='rocket_r')

# %%
# LightGBM
LGBM_model = LGBMClassifier()
# model_evaluation(LGBM_model)

# %%
params = {
    'max_bin': range(255, 300, 5),
    'learning_rate': [0.2, 0.4, 0.6, 0.8, 0.1],
    'num_iterations': range(100, 500, 50),
}

search = GridSearchCV(LGBM_model, params, scoring='f1', verbose=3 )
search.fit(X, y)
# Out:
#    0.3s
# [CV 3/5] END learning_rate=0.1, max_bin=270, num_iterations=100; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_bin=270, num_iterations=100; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_bin=270, num_iterations=100; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_bin=270, num_iterations=150; total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_bin=270, num_iterations=150; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_bin=270, num_iterations=150; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_bin=270, num_iterations=150; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_bin=270, num_iterations=150; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_bin=270, num_iterations=200; total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_bin=270, num_iterations=200; total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_bin=270, num_iterations=200; total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_bin=270, num_iterations=200; total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_bin=270, num_iterations=200; total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_bin=270, num_iterations=250; total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_bin=270, num_iterations=250; total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_bin=270, num_iterations=250; total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_bin=270, num_iterations=250; total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_bin=270, num_iterations=250; total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_bin=270, num_iterations=300; total time=   0.7s
# [CV 2/5] END learning_rate=0.1, max_bin=270, num_iterations=300; total time=   0.7s
# [CV 3/5] END learning_rate=0.1, max_bin=270, num_iterations=300; total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_bin=270, num_iterations=300; total time=   0.7s
# [CV 5/5] END learning_rate=0.1, max_bin=270, num_iterations=300; total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_bin=270, num_iterations=350; total time=   0.8s
# [CV 2/5] END learning_rate=0.1, max_bin=270, num_iterations=350; total time=   0.8s
# [CV 3/5] END learning_rate=0.1, max_bin=270, num_iterations=350; total time=   0.9s
# [CV 4/5] END learning_rate=0.1, max_bin=270, num_iterations=350; total time=   0.9s
# [CV 5/5] END learning_rate=0.1, max_bin=270, num_iterations=350; total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_bin=270, num_iterations=400; total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_bin=270, num_iterations=400; total time=   0.9s
# [CV 3/5] END learning_rate=0.1, max_bin=270, num_iterations=400; total time=   1.0s
# [CV 4/5] END learning_rate=0.1, max_bin=270, num_iterations=400; total time=   0.9s
# [CV 5/5] END learning_rate=0.1, max_bin=270, num_iterations=400; total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_bin=270, num_iterations=450; total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_bin=270, num_iterations=450; total time=   1.1s
# [CV 3/5] END learning_rate=0.1, max_bin=270, num_iterations=450; total time=   1.0s
# [CV 4/5] END learning_rate=0.1, max_bin=270, num_iterations=450; total time=   1.0s
# [CV 5/5] END learning_rate=0.1, max_bin=270, num_iterations=450; total time=   1.2s
# [CV 1/5] END learning_rate=0.1, max_bin=275, num_iterations=100; total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_bin=275, num_iterations=100; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_bin=275, num_iterations=100; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_bin=275, num_iterations=100; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_bin=275, num_iterations=100; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_bin=275, num_iterations=150; total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_bin=275, num_iterations=150; total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_bin=275, num_iterations=150; total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_bin=275, num_iterations=150; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_bin=275, num_iterations=150; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_bin=275, num_iterations=200; total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_bin=275, num_iterations=200; total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_bin=275, num_iterations=200; total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_bin=275, num_iterations=200; total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_bin=275, num_iterations=200; total time=   0.5s
# [CV 1/5] END learning_rate=0.1, max_bin=275, num_iterations=250; total time=   0.7s
# [CV 2/5] END learning_rate=0.1, max_bin=275, num_iterations=250; total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_bin=275, num_iterations=250; total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_bin=275, num_iterations=250; total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_bin=275, num_iterations=250; total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_bin=275, num_iterations=300; total time=   0.7s
# [CV 2/5] END learning_rate=0.1, max_bin=275, num_iterations=300; total time=   0.7s
# [CV 3/5] END learning_rate=0.1, max_bin=275, num_iterations=300; total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_bin=275, num_iterations=300; total time=   1.0s
# [CV 5/5] END learning_rate=0.1, max_bin=275, num_iterations=300; total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_bin=275, num_iterations=350; total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_bin=275, num_iterations=350; total time=   0.9s
# [CV 3/5] END learning_rate=0.1, max_bin=275, num_iterations=350; total time=   0.9s
# [CV 4/5] END learning_rate=0.1, max_bin=275, num_iterations=350; total time=   0.8s
# [CV 5/5] END learning_rate=0.1, max_bin=275, num_iterations=350; total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_bin=275, num_iterations=400; total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_bin=275, num_iterations=400; total time=   0.9s
# [CV 3/5] END learning_rate=0.1, max_bin=275, num_iterations=400; total time=   1.0s
# [CV 4/5] END learning_rate=0.1, max_bin=275, num_iterations=400; total time=   0.9s
# [CV 5/5] END learning_rate=0.1, max_bin=275, num_iterations=400; total time=   1.0s
# [CV 1/5] END learning_rate=0.1, max_bin=275, num_iterations=450; total time=   1.1s
# [CV 2/5] END learning_rate=0.1, max_bin=275, num_iterations=450; total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_bin=275, num_iterations=450; total time=   1.1s
# [CV 4/5] END learning_rate=0.1, max_bin=275, num_iterations=450; total time=   1.0s
# [CV 5/5] END learning_rate=0.1, max_bin=275, num_iterations=450; total time=   1.0s
# [CV 1/5] END learning_rate=0.1, max_bin=280, num_iterations=100; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_bin=280, num_iterations=100; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_bin=280, num_iterations=100; total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_bin=280, num_iterations=100; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_bin=280, num_iterations=100; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_bin=280, num_iterations=150; total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_bin=280, num_iterations=150; total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_bin=280, num_iterations=150; total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_bin=280, num_iterations=150; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_bin=280, num_iterations=150; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_bin=280, num_iterations=200; total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_bin=280, num_iterations=200; total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_bin=280, num_iterations=200; total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_bin=280, num_iterations=200; total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_bin=280, num_iterations=200; total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_bin=280, num_iterations=250; total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_bin=280, num_iterations=250; total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_bin=280, num_iterations=250; total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_bin=280, num_iterations=250; total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_bin=280, num_iterations=250; total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_bin=280, num_iterations=300; total time=   0.8s
# [CV 2/5] END learning_rate=0.1, max_bin=280, num_iterations=300; total time=   0.7s
# [CV 3/5] END learning_rate=0.1, max_bin=280, num_iterations=300; total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_bin=280, num_iterations=300; total time=   0.7s
# [CV 5/5] END learning_rate=0.1, max_bin=280, num_iterations=300; total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_bin=280, num_iterations=350; total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_bin=280, num_iterations=350; total time=   0.9s
# [CV 3/5] END learning_rate=0.1, max_bin=280, num_iterations=350; total time=   0.9s
# [CV 4/5] END learning_rate=0.1, max_bin=280, num_iterations=350; total time=   0.9s
# [CV 5/5] END learning_rate=0.1, max_bin=280, num_iterations=350; total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_bin=280, num_iterations=400; total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_bin=280, num_iterations=400; total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_bin=280, num_iterations=400; total time=   0.9s
# [CV 4/5] END learning_rate=0.1, max_bin=280, num_iterations=400; total time=   1.0s
# [CV 5/5] END learning_rate=0.1, max_bin=280, num_iterations=400; total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_bin=280, num_iterations=450; total time=   1.1s
# [CV 2/5] END learning_rate=0.1, max_bin=280, num_iterations=450; total time=   1.1s
# [CV 3/5] END learning_rate=0.1, max_bin=280, num_iterations=450; total time=   1.2s
# [CV 4/5] END learning_rate=0.1, max_bin=280, num_iterations=450; total time=   1.1s
# [CV 5/5] END learning_rate=0.1, max_bin=280, num_iterations=450; total time=   1.0s
# [CV 1/5] END learning_rate=0.1, max_bin=285, num_iterations=100; total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_bin=285, num_iterations=100; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_bin=285, num_iterations=100; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_bin=285, num_iterations=100; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_bin=285, num_iterations=100; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_bin=285, num_iterations=150; total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_bin=285, num_iterations=150; total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_bin=285, num_iterations=150; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_bin=285, num_iterations=150; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_bin=285, num_iterations=150; total time=   0.5s
# [CV 1/5] END learning_rate=0.1, max_bin=285, num_iterations=200; total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_bin=285, num_iterations=200; total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_bin=285, num_iterations=200; total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_bin=285, num_iterations=200; total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_bin=285, num_iterations=200; total time=   0.5s
# [CV 1/5] END learning_rate=0.1, max_bin=285, num_iterations=250; total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_bin=285, num_iterations=250; total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_bin=285, num_iterations=250; total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_bin=285, num_iterations=250; total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_bin=285, num_iterations=250; total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_bin=285, num_iterations=300; total time=   0.7s
# [CV 2/5] END learning_rate=0.1, max_bin=285, num_iterations=300; total time=   0.7s
# [CV 3/5] END learning_rate=0.1, max_bin=285, num_iterations=300; total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_bin=285, num_iterations=300; total time=   0.7s
# [CV 5/5] END learning_rate=0.1, max_bin=285, num_iterations=300; total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_bin=285, num_iterations=350; total time=   0.8s
# [CV 2/5] END learning_rate=0.1, max_bin=285, num_iterations=350; total time=   0.8s
# [CV 3/5] END learning_rate=0.1, max_bin=285, num_iterations=350; total time=   0.8s
# [CV 4/5] END learning_rate=0.1, max_bin=285, num_iterations=350; total time=   0.8s
# [CV 5/5] END learning_rate=0.1, max_bin=285, num_iterations=350; total time=   0.8s
# [CV 1/5] END learning_rate=0.1, max_bin=285, num_iterations=400; total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_bin=285, num_iterations=400; total time=   0.9s
# [CV 3/5] END learning_rate=0.1, max_bin=285, num_iterations=400; total time=   0.9s
# [CV 4/5] END learning_rate=0.1, max_bin=285, num_iterations=400; total time=   0.9s
# [CV 5/5] END learning_rate=0.1, max_bin=285, num_iterations=400; total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_bin=285, num_iterations=450; total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_bin=285, num_iterations=450; total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_bin=285, num_iterations=450; total time=   1.0s
# [CV 4/5] END learning_rate=0.1, max_bin=285, num_iterations=450; total time=   1.0s
# [CV 5/5] END learning_rate=0.1, max_bin=285, num_iterations=450; total time=   1.0s
# [CV 1/5] END learning_rate=0.1, max_bin=290, num_iterations=100; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_bin=290, num_iterations=100; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_bin=290, num_iterations=100; total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_bin=290, num_iterations=100; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_bin=290, num_iterations=100; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_bin=290, num_iterations=150; total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_bin=290, num_iterations=150; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_bin=290, num_iterations=150; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_bin=290, num_iterations=150; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_bin=290, num_iterations=150; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_bin=290, num_iterations=200; total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_bin=290, num_iterations=200; total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_bin=290, num_iterations=200; total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_bin=290, num_iterations=200; total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_bin=290, num_iterations=200; total time=   0.5s
# [CV 1/5] END learning_rate=0.1, max_bin=290, num_iterations=250; total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_bin=290, num_iterations=250; total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_bin=290, num_iterations=250; total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_bin=290, num_iterations=250; total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_bin=290, num_iterations=250; total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_bin=290, num_iterations=300; total time=   0.7s
# [CV 2/5] END learning_rate=0.1, max_bin=290, num_iterations=300; total time=   0.7s
# [CV 3/5] END learning_rate=0.1, max_bin=290, num_iterations=300; total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_bin=290, num_iterations=300; total time=   0.7s
# [CV 5/5] END learning_rate=0.1, max_bin=290, num_iterations=300; total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_bin=290, num_iterations=350; total time=   0.8s
# [CV 2/5] END learning_rate=0.1, max_bin=290, num_iterations=350; total time=   0.8s
# [CV 3/5] END learning_rate=0.1, max_bin=290, num_iterations=350; total time=   0.8s
# [CV 4/5] END learning_rate=0.1, max_bin=290, num_iterations=350; total time=   0.8s
# [CV 5/5] END learning_rate=0.1, max_bin=290, num_iterations=350; total time=   0.8s
# [CV 1/5] END learning_rate=0.1, max_bin=290, num_iterations=400; total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_bin=290, num_iterations=400; total time=   0.9s
# [CV 3/5] END learning_rate=0.1, max_bin=290, num_iterations=400; total time=   0.9s
# [CV 4/5] END learning_rate=0.1, max_bin=290, num_iterations=400; total time=   0.9s
# [CV 5/5] END learning_rate=0.1, max_bin=290, num_iterations=400; total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_bin=290, num_iterations=450; total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_bin=290, num_iterations=450; total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_bin=290, num_iterations=450; total time=   1.0s
# [CV 4/5] END learning_rate=0.1, max_bin=290, num_iterations=450; total time=   1.0s
# [CV 5/5] END learning_rate=0.1, max_bin=290, num_iterations=450; total time=   1.0s
# [CV 1/5] END learning_rate=0.1, max_bin=295, num_iterations=100; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_bin=295, num_iterations=100; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_bin=295, num_iterations=100; total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_bin=295, num_iterations=100; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_bin=295, num_iterations=100; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_bin=295, num_iterations=150; total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_bin=295, num_iterations=150; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_bin=295, num_iterations=150; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_bin=295, num_iterations=150; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_bin=295, num_iterations=150; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_bin=295, num_iterations=200; total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_bin=295, num_iterations=200; total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_bin=295, num_iterations=200; total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_bin=295, num_iterations=200; total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_bin=295, num_iterations=200; total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_bin=295, num_iterations=250; total time=   0.7s
# [CV 2/5] END learning_rate=0.1, max_bin=295, num_iterations=250; total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_bin=295, num_iterations=250; total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_bin=295, num_iterations=250; total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_bin=295, num_iterations=250; total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_bin=295, num_iterations=300; total time=   0.7s
# [CV 2/5] END learning_rate=0.1, max_bin=295, num_iterations=300; total time=   0.7s
# [CV 3/5] END learning_rate=0.1, max_bin=295, num_iterations=300; total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_bin=295, num_iterations=300; total time=   0.7s
# [CV 5/5] END learning_rate=0.1, max_bin=295, num_iterations=300; total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_bin=295, num_iterations=350; total time=   0.8s
# [CV 2/5] END learning_rate=0.1, max_bin=295, num_iterations=350; total time=   0.8s
# [CV 3/5] END learning_rate=0.1, max_bin=295, num_iterations=350; total time=   0.8s
# [CV 4/5] END learning_rate=0.1, max_bin=295, num_iterations=350; total time=   0.8s
# [CV 5/5] END learning_rate=0.1, max_bin=295, num_iterations=350; total time=   0.8s
# [CV 1/5] END learning_rate=0.1, max_bin=295, num_iterations=400; total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_bin=295, num_iterations=400; total time=   0.9s
# [CV 3/5] END learning_rate=0.1, max_bin=295, num_iterations=400; total time=   0.9s
# [CV 4/5] END learning_rate=0.1, max_bin=295, num_iterations=400; total time=   0.9s
# [CV 5/5] END learning_rate=0.1, max_bin=295, num_iterations=400; total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_bin=295, num_iterations=450; total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_bin=295, num_iterations=450; total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_bin=295, num_iterations=450; total time=   1.0s
# [CV 4/5] END learning_rate=0.1, max_bin=295, num_iterations=450; total time=   1.1s
# [CV 5/5] END learning_rate=0.1, max_bin=295, num_iterations=450; total time=   1.0s
# GridSearchCV(estimator=LGBMClassifier(),
#              param_grid={'learning_rate': [0.2, 0.4, 0.6, 0.8, 0.1],
#                          'max_bin': range(255, 300, 5),
#                          'num_iterations': range(100, 500, 50)},
#              scoring='f1', verbose=3)

# %%
print('Best Score for XGB: {} \nWith params: {}'.format(search.best_score_, search.best_params_))
# Out:
# Best Score for XGB: 0.7445204569007812
# With params: {'learning_rate': 0.1, 'max_bin': 280, 'num_iterations': 150}

# %%
# LGBM_model = LGBMClassifier()
# LGBM_model.fit(X, y)
# y_pred = LGBM_model.predict(data_test_prep)

# my_submission = pd.DataFrame({'PassengerId': data_test['PassengerId'], 'Survived': y_pred})
# my_submission.to_csv('submission_v2.csv', index=False)

# %% [markdown]
# Best Score for XGB: 0.7445204569007812
# With params: {'learning_rate': 0.1, 'max_bin': 280, 'num_iterations': 150}
