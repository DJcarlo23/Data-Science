# %%
import pandas as pd
import umap.umap_ as umap
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px

from plotly.subplots import make_subplots
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold 
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, log_loss

# ML
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

# %%
data_train = pd.read_csv('data/train.csv').drop('id', axis=1)
data_test = pd.read_csv('data/test.csv').drop('id', axis=1)

# %%
data_train_num = data_train

X = data_train_num.drop('target', axis=1)
y = data_train_num['target']

# %%
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X))
# test_scaled = pd.DataFrame(scaler.fit_transform(data_test))

log_pred = np.zeros((len(X), 4))
test_pred = np.zeros((len(data_test), 4))

# %% [markdown]
# <h3> Catboost  </h3>

# %%
lg_model = LGBMClassifier()

# %%
# %%time

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for fold_, (train_index, val_index) in enumerate(skf.split(X, y)):
    print('Fold: ', fold_)
    model = lg_model.fit(
        X.iloc[train_index],
        y.iloc[train_index],
        eval_set = [(X.iloc[train_index], y.iloc[train_index]), (X.iloc[val_index], y.iloc[val_index])],
        eval_metric = 'multi_logloss'
        early_stopping_rounds = 50,
        verbose = 10
    )

    temp_pred = model.predict_proba(X.iloc[val_index])
    log_pred[val_index] = temp_pred

    print(f'Log Loss: {log_loss(y.iloc[val_index], temp_pred)}')

    temp_test = model.predict_proba(data_test)
    test_pred += temp_test

test_pred1 = test_pred/5

print(f'Overall Log Loss: {log_loss(y, log_pred)}')

# %%
cat_model = CatBoostClassifier()

# %%
# %%time

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

for fold_, (train_index, val_index) in enumerate(skf.split(X, y)):
    print('Fold: ', fold_)
    model = cat_model.fit(
        X.iloc[train_index],
        y.iloc[train_index],
        eval_set = [(X.iloc[train_index], y.iloc[train_index]), (X.iloc[val_index], y.iloc[val_index])],
        early_stopping_rounds = 50,
        verbose = 10
    )

    temp_pred = model.predict_proba(X.iloc[val_index])
    log_pred[val_index] = temp_pred

    print(f'Log Loss: {log_loss(y.iloc[val_index], temp_pred)}')

    temp_test = model.predict_proba(data_test)
    test_pred += temp_test

test_pred2 = test_pred/10

print(f'Overall Log Loss: {log_loss(y, log_pred)}')
# Out:
#  1.0951644	best: 1.0951644 (80)	total: 2.43s	remaining: 27.6s
# 90:	learn: 1.0872008	test: 1.0872008	test1: 1.0942287	best: 1.0942287 (90)	total: 2.75s	remaining: 27.5s
# 100:	learn: 1.0853168	test: 1.0853168	test1: 1.0935055	best: 1.0935055 (100)	total: 3.05s	remaining: 27.2s
# 110:	learn: 1.0834235	test: 1.0834235	test1: 1.0926671	best: 1.0926671 (110)	total: 3.35s	remaining: 26.8s
# 120:	learn: 1.0815685	test: 1.0815685	test1: 1.0923056	best: 1.0922761 (117)	total: 3.64s	remaining: 26.4s
# 130:	learn: 1.0799798	test: 1.0799798	test1: 1.0917776	best: 1.0917776 (130)	total: 3.97s	remaining: 26.4s
# 140:	learn: 1.0783451	test: 1.0783451	test1: 1.0914023	best: 1.0914023 (140)	total: 4.28s	remaining: 26.1s
# 150:	learn: 1.0768035	test: 1.0768035	test1: 1.0909855	best: 1.0909855 (150)	total: 4.61s	remaining: 25.9s
# 160:	learn: 1.0753976	test: 1.0753976	test1: 1.0906919	best: 1.0906542 (159)	total: 4.92s	remaining: 25.7s
# 170:	learn: 1.0741034	test: 1.0741034	test1: 1.0905089	best: 1.0905089 (170)	total: 5.25s	remaining: 25.4s
# 180:	learn: 1.0729140	test: 1.0729140	test1: 1.0902672	best: 1.0902672 (180)	total: 5.57s	remaining: 25.2s
# 190:	learn: 1.0715733	test: 1.0715733	test1: 1.0902596	best: 1.0901928 (183)	total: 5.91s	remaining: 25s
# 200:	learn: 1.0705263	test: 1.0705263	test1: 1.0901258	best: 1.0901113 (196)	total: 6.24s	remaining: 24.8s
# 210:	learn: 1.0690010	test: 1.0690010	test1: 1.0899412	best: 1.0899412 (210)	total: 6.55s	remaining: 24.5s
# 220:	learn: 1.0679650	test: 1.0679650	test1: 1.0898271	best: 1.0898117 (218)	total: 6.85s	remaining: 24.2s
# 230:	learn: 1.0668005	test: 1.0668005	test1: 1.0899363	best: 1.0897417 (226)	total: 7.18s	remaining: 23.9s
# 240:	learn: 1.0656661	test: 1.0656661	test1: 1.0897155	best: 1.0897155 (240)	total: 7.51s	remaining: 23.7s
# 250:	learn: 1.0645557	test: 1.0645557	test1: 1.0895401	best: 1.0895178 (249)	total: 7.83s	remaining: 23.4s
# 260:	learn: 1.0634950	test: 1.0634950	test1: 1.0894373	best: 1.0894245 (259)	total: 8.15s	remaining: 23.1s
# 270:	learn: 1.0626632	test: 1.0626632	test1: 1.0892928	best: 1.0892928 (270)	total: 8.46s	remaining: 22.8s
# 280:	learn: 1.0615587	test: 1.0615587	test1: 1.0891156	best: 1.0891105 (279)	total: 8.78s	remaining: 22.5s
# 290:	learn: 1.0606557	test: 1.0606557	test1: 1.0890319	best: 1.0890319 (290)	total: 9.05s	remaining: 22.1s
# 300:	learn: 1.0596775	test: 1.0596775	test1: 1.0891080	best: 1.0890319 (290)	total: 9.33s	remaining: 21.7s
# 310:	learn: 1.0588144	test: 1.0588144	test1: 1.0891560	best: 1.0890319 (290)	total: 9.62s	remaining: 21.3s
# 320:	learn: 1.0577333	test: 1.0577333	test1: 1.0891608	best: 1.0890319 (290)	total: 9.98s	remaining: 21.1s
# 330:	learn: 1.0568072	test: 1.0568072	test1: 1.0888972	best: 1.0888972 (330)	total: 10.3s	remaining: 20.8s
# 340:	learn: 1.0560569	test: 1.0560569	test1: 1.0889329	best: 1.0888972 (330)	total: 10.6s	remaining: 20.6s
# 350:	learn: 1.0549762	test: 1.0549762	test1: 1.0890581	best: 1.0888972 (330)	total: 11s	remaining: 20.3s
# 360:	learn: 1.0541054	test: 1.0541054	test1: 1.0890955	best: 1.0888972 (330)	total: 11.3s	remaining: 20s
# 370:	learn: 1.0532196	test: 1.0532196	test1: 1.0891827	best: 1.0888972 (330)	total: 11.6s	remaining: 19.6s
# 380:	learn: 1.0522674	test: 1.0522674	test1: 1.0891598	best: 1.0888972 (330)	total: 11.9s	remaining: 19.3s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.088897179
# bestIteration = 330
#
# Shrink model to first 331 iterations.
# Log Loss: 1.0888971785917936
# Fold:  6
# Learning rate set to 0.118144
# 0:	learn: 1.3195702	test: 1.3195702	test1: 1.3194792	best: 1.3194792 (0)	total: 30.9ms	remaining: 30.9s
# 10:	learn: 1.1324197	test: 1.1324197	test1: 1.1328542	best: 1.1328542 (10)	total: 289ms	remaining: 26s
# 20:	learn: 1.1102315	test: 1.1102315	test1: 1.1120941	best: 1.1120941 (20)	total: 594ms	remaining: 27.7s
# 30:	learn: 1.1034458	test: 1.1034458	test1: 1.1070031	best: 1.1070031 (30)	total: 910ms	remaining: 28.4s
# 40:	learn: 1.0990093	test: 1.0990093	test1: 1.1044590	best: 1.1044590 (40)	total: 1.26s	remaining: 29.6s
# 50:	learn: 1.0955634	test: 1.0955634	test1: 1.1024611	best: 1.1024611 (50)	total: 1.59s	remaining: 29.6s
# 60:	learn: 1.0931723	test: 1.0931723	test1: 1.1011660	best: 1.1011660 (60)	total: 1.89s	remaining: 29s
# 70:	learn: 1.0907490	test: 1.0907490	test1: 1.0999940	best: 1.0999940 (70)	total: 2.24s	remaining: 29.3s
# 80:	learn: 1.0886183	test: 1.0886183	test1: 1.0989014	best: 1.0989014 (80)	total: 2.51s	remaining: 28.5s
# 90:	learn: 1.0865456	test: 1.0865456	test1: 1.0980841	best: 1.0980841 (90)	total: 2.81s	remaining: 28.1s
# 100:	learn: 1.0844377	test: 1.0844377	test1: 1.0972660	best: 1.0972660 (100)	total: 3.12s	remaining: 27.8s
# 110:	learn: 1.0823853	test: 1.0823853	test1: 1.0966099	best: 1.0966099 (110)	total: 3.42s	remaining: 27.4s
# 120:	learn: 1.0807465	test: 1.0807465	test1: 1.0960463	best: 1.0960288 (119)	total: 3.71s	remaining: 27s
# 130:	learn: 1.0793130	test: 1.0793130	test1: 1.0957011	best: 1.0957011 (130)	total: 4s	remaining: 26.5s
# 140:	learn: 1.0778871	test: 1.0778871	test1: 1.0955256	best: 1.0955111 (138)	total: 4.27s	remaining: 26s
# 150:	learn: 1.0765117	test: 1.0765117	test1: 1.0951789	best: 1.0951789 (150)	total: 4.61s	remaining: 25.9s
# 160:	learn: 1.0750545	test: 1.0750545	test1: 1.0949424	best: 1.0949424 (160)	total: 4.93s	remaining: 25.7s
# 170:	learn: 1.0737654	test: 1.0737654	test1: 1.0947371	best: 1.0947371 (170)	total: 5.24s	remaining: 25.4s
# 180:	learn: 1.0726020	test: 1.0726020	test1: 1.0946785	best: 1.0946785 (180)	total: 5.57s	remaining: 25.2s
# 190:	learn: 1.0710964	test: 1.0710964	test1: 1.0946476	best: 1.0945790 (186)	total: 5.87s	remaining: 24.9s
# 200:	learn: 1.0699960	test: 1.0699960	test1: 1.0945305	best: 1.0945305 (200)	total: 6.16s	remaining: 24.5s
# 210:	learn: 1.0689924	test: 1.0689924	test1: 1.0943804	best: 1.0943660 (209)	total: 6.46s	remaining: 24.2s
# 220:	learn: 1.0678518	test: 1.0678518	test1: 1.0943165	best: 1.0942765 (218)	total: 6.74s	remaining: 23.7s
# 230:	learn: 1.0666405	test: 1.0666405	test1: 1.0941125	best: 1.0940877 (229)	total: 7.04s	remaining: 23.4s
# 240:	learn: 1.0657228	test: 1.0657228	test1: 1.0938435	best: 1.0938435 (240)	total: 7.32s	remaining: 23.1s
# 250:	learn: 1.0648394	test: 1.0648394	test1: 1.0939009	best: 1.0938405 (244)	total: 7.62s	remaining: 22.7s
# 260:	learn: 1.0636864	test: 1.0636864	test1: 1.0939111	best: 1.0938405 (244)	total: 7.93s	remaining: 22.5s
# 270:	learn: 1.0626851	test: 1.0626851	test1: 1.0939989	best: 1.0938405 (244)	total: 8.24s	remaining: 22.2s
# 280:	learn: 1.0615824	test: 1.0615824	test1: 1.0939206	best: 1.0938405 (244)	total: 8.53s	remaining: 21.8s
# 290:	learn: 1.0605100	test: 1.0605100	test1: 1.0940795	best: 1.0938405 (244)	total: 8.83s	remaining: 21.5s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.093840455
# bestIteration = 244
#
# Shrink model to first 245 iterations.
# Log Loss: 1.0938404553107135
# Fold:  7
# Learning rate set to 0.118144
# 0:	learn: 1.3195339	test: 1.3195339	test1: 1.3196549	best: 1.3196549 (0)	total: 31.5ms	remaining: 31.5s
# 10:	learn: 1.1325045	test: 1.1325045	test1: 1.1331726	best: 1.1331726 (10)	total: 283ms	remaining: 25.4s
# 20:	learn: 1.1102438	test: 1.1102438	test1: 1.1120999	best: 1.1120999 (20)	total: 617ms	remaining: 28.8s
# 30:	learn: 1.1032204	test: 1.1032204	test1: 1.1065134	best: 1.1065134 (30)	total: 945ms	remaining: 29.5s
# 40:	learn: 1.0988617	test: 1.0988617	test1: 1.1037763	best: 1.1037763 (40)	total: 1.28s	remaining: 30.1s
# 50:	learn: 1.0956693	test: 1.0956693	test1: 1.1019351	best: 1.1019351 (50)	total: 1.6s	remaining: 29.7s
# 60:	learn: 1.0927041	test: 1.0927041	test1: 1.1004449	best: 1.1004449 (60)	total: 1.91s	remaining: 29.5s
# 70:	learn: 1.0904876	test: 1.0904876	test1: 1.0991881	best: 1.0991881 (70)	total: 2.22s	remaining: 29s
# 80:	learn: 1.0882836	test: 1.0882836	test1: 1.0977792	best: 1.0977792 (80)	total: 2.53s	remaining: 28.7s
# 90:	learn: 1.0862815	test: 1.0862815	test1: 1.0968014	best: 1.0968014 (90)	total: 2.82s	remaining: 28.2s
# 100:	learn: 1.0843996	test: 1.0843996	test1: 1.0959395	best: 1.0959395 (100)	total: 3.1s	remaining: 27.6s
# 110:	learn: 1.0824227	test: 1.0824227	test1: 1.0951612	best: 1.0951612 (110)	total: 3.4s	remaining: 27.2s
# 120:	learn: 1.0805160	test: 1.0805160	test1: 1.0945407	best: 1.0945407 (120)	total: 3.7s	remaining: 26.9s
# 130:	learn: 1.0788281	test: 1.0788281	test1: 1.0939186	best: 1.0939186 (130)	total: 3.98s	remaining: 26.4s
# 140:	learn: 1.0773064	test: 1.0773064	test1: 1.0936707	best: 1.0936429 (139)	total: 4.28s	remaining: 26.1s
# 150:	learn: 1.0759806	test: 1.0759806	test1: 1.0931718	best: 1.0931718 (150)	total: 4.56s	remaining: 25.6s
# 160:	learn: 1.0747227	test: 1.0747227	test1: 1.0928903	best: 1.0928903 (160)	total: 4.84s	remaining: 25.2s
# 170:	learn: 1.0733923	test: 1.0733923	test1: 1.0927686	best: 1.0926914 (166)	total: 5.12s	remaining: 24.8s
# 180:	learn: 1.0724260	test: 1.0724260	test1: 1.0926757	best: 1.0926445 (175)	total: 5.42s	remaining: 24.5s
# 190:	learn: 1.0711222	test: 1.0711222	test1: 1.0926077	best: 1.0925808 (183)	total: 5.73s	remaining: 24.3s
# 200:	learn: 1.0699944	test: 1.0699944	test1: 1.0922827	best: 1.0922827 (200)	total: 6.03s	remaining: 24s
# 210:	learn: 1.0687303	test: 1.0687303	test1: 1.0921438	best: 1.0921438 (210)	total: 6.34s	remaining: 23.7s
# 220:	learn: 1.0677973	test: 1.0677973	test1: 1.0920223	best: 1.0920223 (220)	total: 6.65s	remaining: 23.4s
# 230:	learn: 1.0667359	test: 1.0667359	test1: 1.0918229	best: 1.0917505 (226)	total: 6.95s	remaining: 23.1s
# 240:	learn: 1.0654898	test: 1.0654898	test1: 1.0915847	best: 1.0915847 (240)	total: 7.26s	remaining: 22.9s
# 250:	learn: 1.0644614	test: 1.0644614	test1: 1.0914002	best: 1.0913929 (249)	total: 7.55s	remaining: 22.5s
# 260:	learn: 1.0633521	test: 1.0633521	test1: 1.0913101	best: 1.0913101 (260)	total: 7.87s	remaining: 22.3s
# 270:	learn: 1.0621600	test: 1.0621600	test1: 1.0912076	best: 1.0911845 (263)	total: 8.17s	remaining: 22s
# 280:	learn: 1.0612221	test: 1.0612221	test1: 1.0909492	best: 1.0909492 (280)	total: 8.48s	remaining: 21.7s
# 290:	learn: 1.0600933	test: 1.0600933	test1: 1.0910094	best: 1.0909306 (284)	total: 8.79s	remaining: 21.4s
# 300:	learn: 1.0590178	test: 1.0590178	test1: 1.0910858	best: 1.0909306 (284)	total: 9.12s	remaining: 21.2s
# 310:	learn: 1.0581258	test: 1.0581258	test1: 1.0911013	best: 1.0909306 (284)	total: 9.42s	remaining: 20.9s
# 320:	learn: 1.0573096	test: 1.0573096	test1: 1.0910045	best: 1.0909306 (284)	total: 9.73s	remaining: 20.6s
# 330:	learn: 1.0562642	test: 1.0562642	test1: 1.0909675	best: 1.0909306 (284)	total: 10.1s	remaining: 20.4s
# 340:	learn: 1.0554045	test: 1.0554045	test1: 1.0909807	best: 1.0909145 (334)	total: 10.4s	remaining: 20.2s
# 350:	learn: 1.0544822	test: 1.0544822	test1: 1.0909408	best: 1.0908901 (346)	total: 10.8s	remaining: 19.9s
# 360:	learn: 1.0536253	test: 1.0536253	test1: 1.0908557	best: 1.0907757 (354)	total: 11.1s	remaining: 19.6s
# 370:	learn: 1.0529959	test: 1.0529959	test1: 1.0909078	best: 1.0907757 (354)	total: 11.4s	remaining: 19.3s
# 380:	learn: 1.0521256	test: 1.0521256	test1: 1.0908630	best: 1.0907757 (354)	total: 11.7s	remaining: 19s
# 390:	learn: 1.0510415	test: 1.0510415	test1: 1.0908647	best: 1.0907757 (354)	total: 12s	remaining: 18.7s
# 400:	learn: 1.0500241	test: 1.0500241	test1: 1.0907438	best: 1.0907309 (399)	total: 12.3s	remaining: 18.4s
# 410:	learn: 1.0491546	test: 1.0491546	test1: 1.0908287	best: 1.0907161 (404)	total: 12.7s	remaining: 18.1s
# 420:	learn: 1.0484306	test: 1.0484306	test1: 1.0907562	best: 1.0907161 (404)	total: 13s	remaining: 17.8s
# 430:	learn: 1.0475526	test: 1.0475526	test1: 1.0907177	best: 1.0907161 (404)	total: 13.3s	remaining: 17.5s
# 440:	learn: 1.0467122	test: 1.0467122	test1: 1.0908264	best: 1.0907161 (404)	total: 13.6s	remaining: 17.2s
# 450:	learn: 1.0458855	test: 1.0458855	test1: 1.0908200	best: 1.0907161 (404)	total: 13.9s	remaining: 16.9s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.090716145
# bestIteration = 404
#
# Shrink model to first 405 iterations.
# Log Loss: 1.090716145401981
# Fold:  8
# Learning rate set to 0.118144
# 0:	learn: 1.3195609	test: 1.3195609	test1: 1.3195587	best: 1.3195587 (0)	total: 28.4ms	remaining: 28.3s
# 10:	learn: 1.1325711	test: 1.1325711	test1: 1.1326565	best: 1.1326565 (10)	total: 296ms	remaining: 26.6s
# 20:	learn: 1.1108335	test: 1.1108335	test1: 1.1116412	best: 1.1116412 (20)	total: 604ms	remaining: 28.2s
# 30:	learn: 1.1036388	test: 1.1036388	test1: 1.1059725	best: 1.1059725 (30)	total: 937ms	remaining: 29.3s
# 40:	learn: 1.0990524	test: 1.0990524	test1: 1.1032593	best: 1.1032593 (40)	total: 1.26s	remaining: 29.4s
# 50:	learn: 1.0957476	test: 1.0957476	test1: 1.1013335	best: 1.1013335 (50)	total: 1.6s	remaining: 29.9s
# 60:	learn: 1.0928891	test: 1.0928891	test1: 1.0996212	best: 1.0996212 (60)	total: 2.02s	remaining: 31.2s
# 70:	learn: 1.0904762	test: 1.0904762	test1: 1.0981722	best: 1.0981722 (70)	total: 2.33s	remaining: 30.5s
# 80:	learn: 1.0887009	test: 1.0887009	test1: 1.0971115	best: 1.0971115 (80)	total: 2.69s	remaining: 30.5s
# 90:	learn: 1.0866529	test: 1.0866529	test1: 1.0961867	best: 1.0961737 (89)	total: 3s	remaining: 30s
# 100:	learn: 1.0845027	test: 1.0845027	test1: 1.0952889	best: 1.0952889 (100)	total: 3.32s	remaining: 29.5s
# 110:	learn: 1.0825266	test: 1.0825266	test1: 1.0944397	best: 1.0944397 (110)	total: 3.67s	remaining: 29.4s
# 120:	learn: 1.0807144	test: 1.0807144	test1: 1.0940773	best: 1.0940773 (120)	total: 4.04s	remaining: 29.3s
# 130:	learn: 1.0790298	test: 1.0790298	test1: 1.0936099	best: 1.0936099 (130)	total: 4.35s	remaining: 28.9s
# 140:	learn: 1.0776229	test: 1.0776229	test1: 1.0933022	best: 1.0933022 (140)	total: 4.65s	remaining: 28.3s
# 150:	learn: 1.0763355	test: 1.0763355	test1: 1.0931569	best: 1.0931569 (150)	total: 4.95s	remaining: 27.9s
# 160:	learn: 1.0749704	test: 1.0749704	test1: 1.0930128	best: 1.0930128 (160)	total: 5.27s	remaining: 27.4s
# 170:	learn: 1.0736169	test: 1.0736169	test1: 1.0928362	best: 1.0928117 (168)	total: 5.57s	remaining: 27s
# 180:	learn: 1.0722621	test: 1.0722621	test1: 1.0926007	best: 1.0926007 (180)	total: 5.88s	remaining: 26.6s
# 190:	learn: 1.0711281	test: 1.0711281	test1: 1.0925850	best: 1.0925850 (190)	total: 6.2s	remaining: 26.3s
# 200:	learn: 1.0700193	test: 1.0700193	test1: 1.0926523	best: 1.0925850 (190)	total: 6.52s	remaining: 25.9s
# 210:	learn: 1.0689104	test: 1.0689104	test1: 1.0925889	best: 1.0924912 (204)	total: 6.85s	remaining: 25.6s
# 220:	learn: 1.0678082	test: 1.0678082	test1: 1.0923123	best: 1.0923114 (219)	total: 7.15s	remaining: 25.2s
# 230:	learn: 1.0667864	test: 1.0667864	test1: 1.0921472	best: 1.0921472 (230)	total: 7.46s	remaining: 24.8s
# 240:	learn: 1.0656004	test: 1.0656004	test1: 1.0922475	best: 1.0921472 (230)	total: 7.78s	remaining: 24.5s
# 250:	learn: 1.0644737	test: 1.0644737	test1: 1.0921611	best: 1.0921057 (243)	total: 8.1s	remaining: 24.2s
# 260:	learn: 1.0635063	test: 1.0635063	test1: 1.0921762	best: 1.0921023 (253)	total: 8.4s	remaining: 23.8s
# 270:	learn: 1.0624917	test: 1.0624917	test1: 1.0920905	best: 1.0920568 (267)	total: 8.71s	remaining: 23.4s
# 280:	learn: 1.0616746	test: 1.0616746	test1: 1.0920623	best: 1.0920489 (279)	total: 9.01s	remaining: 23s
# 290:	learn: 1.0605969	test: 1.0605969	test1: 1.0920106	best: 1.0920106 (290)	total: 9.31s	remaining: 22.7s
# 300:	learn: 1.0595657	test: 1.0595657	test1: 1.0919214	best: 1.0918501 (297)	total: 9.61s	remaining: 22.3s
# 310:	learn: 1.0586764	test: 1.0586764	test1: 1.0919422	best: 1.0918501 (297)	total: 9.96s	remaining: 22.1s
# 320:	learn: 1.0578492	test: 1.0578492	test1: 1.0919487	best: 1.0918501 (297)	total: 10.3s	remaining: 21.7s
# 330:	learn: 1.0569318	test: 1.0569318	test1: 1.0919517	best: 1.0918501 (297)	total: 10.6s	remaining: 21.4s
# 340:	learn: 1.0560217	test: 1.0560217	test1: 1.0920008	best: 1.0918501 (297)	total: 10.9s	remaining: 21s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.091850057
# bestIteration = 297
#
# Shrink model to first 298 iterations.
# Log Loss: 1.09185005740237
# Fold:  9
# Learning rate set to 0.118144
# 0:	learn: 1.3195270	test: 1.3195270	test1: 1.3196793	best: 1.3196793 (0)	total: 35.8ms	remaining: 35.7s
# 10:	learn: 1.1325884	test: 1.1325884	test1: 1.1329829	best: 1.1329829 (10)	total: 329ms	remaining: 29.6s
# 20:	learn: 1.1105176	test: 1.1105176	test1: 1.1116762	best: 1.1116762 (20)	total: 645ms	remaining: 30.1s
# 30:	learn: 1.1034617	test: 1.1034617	test1: 1.1059569	best: 1.1059569 (30)	total: 1.01s	remaining: 31.8s
# 40:	learn: 1.0993359	test: 1.0993359	test1: 1.1028390	best: 1.1028390 (40)	total: 1.34s	remaining: 31.4s
# 50:	learn: 1.0960398	test: 1.0960398	test1: 1.1009274	best: 1.1009274 (50)	total: 1.67s	remaining: 31.1s
# 60:	learn: 1.0931728	test: 1.0931728	test1: 1.0993112	best: 1.0993112 (60)	total: 2.04s	remaining: 31.3s
# 70:	learn: 1.0910110	test: 1.0910110	test1: 1.0981838	best: 1.0981838 (70)	total: 2.34s	remaining: 30.6s
# 80:	learn: 1.0891922	test: 1.0891922	test1: 1.0974663	best: 1.0974663 (80)	total: 2.64s	remaining: 30s
# 90:	learn: 1.0873071	test: 1.0873071	test1: 1.0965478	best: 1.0965478 (90)	total: 2.96s	remaining: 29.6s
# 100:	learn: 1.0852578	test: 1.0852578	test1: 1.0957648	best: 1.0957648 (100)	total: 3.3s	remaining: 29.3s
# 110:	learn: 1.0833599	test: 1.0833599	test1: 1.0953913	best: 1.0953090 (107)	total: 3.63s	remaining: 29.1s
# 120:	learn: 1.0813787	test: 1.0813787	test1: 1.0945429	best: 1.0945429 (120)	total: 3.95s	remaining: 28.7s
# 130:	learn: 1.0798368	test: 1.0798368	test1: 1.0941090	best: 1.0941090 (130)	total: 4.29s	remaining: 28.5s
# 140:	learn: 1.0781511	test: 1.0781511	test1: 1.0938901	best: 1.0938743 (139)	total: 4.63s	remaining: 28.2s
# 150:	learn: 1.0766291	test: 1.0766291	test1: 1.0933250	best: 1.0932903 (149)	total: 4.97s	remaining: 28s
# 160:	learn: 1.0751271	test: 1.0751271	test1: 1.0928831	best: 1.0928398 (159)	total: 5.32s	remaining: 27.7s
# 170:	learn: 1.0739009	test: 1.0739009	test1: 1.0926610	best: 1.0926574 (168)	total: 5.66s	remaining: 27.4s
# 180:	learn: 1.0726831	test: 1.0726831	test1: 1.0925337	best: 1.0924930 (178)	total: 6s	remaining: 27.1s
# 190:	learn: 1.0714791	test: 1.0714791	test1: 1.0923394	best: 1.0923394 (190)	total: 6.34s	remaining: 26.9s
# 200:	learn: 1.0701861	test: 1.0701861	test1: 1.0920880	best: 1.0920289 (198)	total: 6.69s	remaining: 26.6s
# 210:	learn: 1.0691282	test: 1.0691282	test1: 1.0921494	best: 1.0920289 (198)	total: 7.04s	remaining: 26.3s
# 220:	learn: 1.0680643	test: 1.0680643	test1: 1.0919501	best: 1.0919269 (218)	total: 7.35s	remaining: 25.9s
# 230:	learn: 1.0671114	test: 1.0671114	test1: 1.0918532	best: 1.0918399 (226)	total: 7.64s	remaining: 25.4s
# 240:	learn: 1.0660288	test: 1.0660288	test1: 1.0918349	best: 1.0917547 (237)	total: 7.95s	remaining: 25s
# 250:	learn: 1.0650617	test: 1.0650617	test1: 1.0918366	best: 1.0917460 (244)	total: 8.23s	remaining: 24.6s
# 260:	learn: 1.0640015	test: 1.0640015	test1: 1.0917701	best: 1.0917226 (254)	total: 8.54s	remaining: 24.2s
# 270:	learn: 1.0630558	test: 1.0630558	test1: 1.0914881	best: 1.0914881 (270)	total: 8.85s	remaining: 23.8s
# 280:	learn: 1.0620502	test: 1.0620502	test1: 1.0913973	best: 1.0913970 (276)	total: 9.13s	remaining: 23.4s
# 290:	learn: 1.0609884	test: 1.0609884	test1: 1.0914554	best: 1.0913567 (286)	total: 9.41s	remaining: 22.9s
# 300:	learn: 1.0599936	test: 1.0599936	test1: 1.0913510	best: 1.0913510 (300)	total: 9.69s	remaining: 22.5s
# 310:	learn: 1.0590847	test: 1.0590847	test1: 1.0912415	best: 1.0912415 (310)	total: 9.96s	remaining: 22.1s
# 320:	learn: 1.0582259	test: 1.0582259	test1: 1.0912567	best: 1.0911500 (317)	total: 10.2s	remaining: 21.6s
# 330:	learn: 1.0572594	test: 1.0572594	test1: 1.0913523	best: 1.0911500 (317)	total: 10.5s	remaining: 21.2s
# 340:	learn: 1.0562628	test: 1.0562628	test1: 1.0913117	best: 1.0911500 (317)	total: 10.8s	remaining: 20.8s
# 350:	learn: 1.0553518	test: 1.0553518	test1: 1.0913155	best: 1.0911500 (317)	total: 11s	remaining: 20.4s
# 360:	learn: 1.0545322	test: 1.0545322	test1: 1.0912793	best: 1.0911500 (317)	total: 11.3s	remaining: 20s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 1.091149976
# bestIteration = 317
#
# Shrink model to first 318 iterations.
# Log Loss: 1.0911499762441252
# Overall Log Loss: 1.0924621913282957
# Wall time: 1min 53s

# %%
df_pred1 = pd.DataFrame(test_pred1)
df_pred2 = pd.DataFrame(test_pred2)

# %%
df_pred1
# Out:
#               0         1         2         3
# 0      0.092975  0.615122  0.169662  0.122241
# 1      0.085693  0.681441  0.148447  0.084420
# 2      0.086204  0.622103  0.184109  0.107584
# 3      0.084022  0.531593  0.282916  0.101468
# 4      0.072276  0.610124  0.196527  0.121074
# ...         ...       ...       ...       ...
# 49995  0.086505  0.723997  0.127859  0.061639
# 49996  0.083712  0.638884  0.138881  0.138523
# 49997  0.085968  0.523624  0.221560  0.168847
# 49998  0.077516  0.590777  0.166377  0.165331
# 49999  0.091262  0.576456  0.190814  0.141469
#
# [50000 rows x 4 columns]

# %%
df_pred2

# %%
data_test1 = pd.read_csv('data/sample_submission.csv').drop(['Class_1', 'Class_2', 'Class_3', 'Class_4'], axis=1)

data_test1['Class_1'] = df_pred1[0]
data_test1['Class_2'] = df_pred1[1]
data_test1['Class_3'] = df_pred1[2]
data_test1['Class_4'] = df_pred1[3]

# %%
data_test2 = pd.read_csv('data/sample_submission.csv').drop(['Class_1', 'Class_2', 'Class_3', 'Class_4'], axis=1)

data_test2['Class_1'] = df_pred2[0]
data_test2['Class_2'] = df_pred2[1]
data_test2['Class_3'] = df_pred2[2]
data_test2['Class_4'] = df_pred2[3]

# %%
data_test
# Out:
#            id   Class_1   Class_2   Class_3   Class_4
# 0      100000  0.092975  0.615122  0.169662  0.122241
# 1      100001  0.085693  0.681441  0.148447  0.084420
# 2      100002  0.086204  0.622103  0.184109  0.107584
# 3      100003  0.084022  0.531593  0.282916  0.101468
# 4      100004  0.072276  0.610124  0.196527  0.121074
# ...       ...       ...       ...       ...       ...
# 49995  149995  0.086505  0.723997  0.127859  0.061639
# 49996  149996  0.083712  0.638884  0.138881  0.138523
# 49997  149997  0.085968  0.523624  0.221560  0.168847
# 49998  149998  0.077516  0.590777  0.166377  0.165331
# 49999  149999  0.091262  0.576456  0.190814  0.141469
#
# [50000 rows x 5 columns]

# %%
data_test.to_csv('submission_v3.csv', index=False)
